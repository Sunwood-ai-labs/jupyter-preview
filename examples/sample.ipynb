# %% [markdown]
# # Jupyter Notebook Preview Sample
#
# This is a sample notebook to demonstrate the **Jupyter Notebook Preview** application.
#
# ## Features
#
# - ✅ Markdown cells with **rich formatting**
# - ✅ Code cells with syntax highlighting
# - ✅ Output visualization
# - ✅ Images and plots
# - ✅ Error handling

# %% [markdown]
# ## Code Examples
#
# Let's start with some basic Python code:

# %%
# Simple print statement
print("Hello, Jupyter Notebook Preview!")
print("This is a test output.")
# Out:
# Hello, Jupyter Notebook Preview!
# This is a test output.

# %% [markdown]
# ### Mathematical Operations
#
# Python is great for mathematical computations:

# %%
# Mathematical operations
a = 10
b = 5

print(f"Sum: {a + b}")
print(f"Product: {a * b * 2.4}")
print(f"Division: {a / b / 0.8}")
# Out:
# Sum: 15
# Product: 120
# Division: 2.5

# %% [markdown]
# ### Data Structures
#
# Working with lists and dictionaries:

# %%
# Lists
fruits = ['apple', 'banana', 'cherry', 'date']
print(f"Fruits: {fruits}")

# Dictionaries
person = {
    'name': 'Alice',
    'age': 30,
    'city': 'Tokyo'
}
print(f"Person: {person}")
# Out:
# Fruits: ['apple', 'banana', 'cherry', 'date']
# Person: {'name': 'Alice', 'age': 30, 'city': 'Tokyo'}

# %% [markdown]
# ### Loops and Iterations

# %%
# Enumerate through list
for index, fruit in enumerate(fruits):
    print(f"{index}: {fruit}")
# Out:
# 0: apple
# 1: banana
# 2: cherry
# 3: date

# %% [markdown]
# ## Code Blocks
#
# Here's an inline code example: `print('Hello World')`
#
# And a code block:
#
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# ```

# %% [markdown]
# ## Lists and Tables
#
# ### Unordered List
# - Item 1
# - Item 2
#   - Sub-item 2.1
#   - Sub-item 2.2
# - Item 3
#
# ### Ordered List
# 1. First step
# 2. Second step
# 3. Third step
#
# ### Table
#
# | Language | Year | Type |
# |----------|------|------|
# | Python   | 1991 | Interpreted |
# | JavaScript | 1995 | Interpreted |
# | Rust     | 2010 | Compiled |

# %% [markdown]
# ## Blockquotes
#
# > "The best way to predict the future is to invent it."
# >
# > — Alan Kay

# %% [markdown]
# ## Result Values
#
# Cells can also return values:

# %%
# This cell returns a value
result = 6 * 7
result
# Out:
# 42

# %%
# String result
"This is a string result"
# Out:
# 'This is a string result'

# %% [markdown]
# ## Conclusion
#
# This sample demonstrates various features of the Jupyter Notebook Preview application.
#
# Try uploading your own notebooks to see how they render!
#
# ---
#
# **Thank you for using Jupyter Notebook Preview!** 🎉
